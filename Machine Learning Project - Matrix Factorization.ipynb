# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle
import warnings

# %%
reduced_books_users_ratings = pd.read_csv("data/clean/reduced_books_users_ratings.csv")
books_users_ratings = pd.read_csv("data/clean/books_users_ratings.csv")

# %%
reduced_books_users_ratings.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'user_id', 'isbn', 'book_rating',
#        'book_title', 'book_author', 'year_of_publication', 'publisher',
#        'unique_isbn', 'Unnamed: 0.1.1', 'age', 'city', 'state', 'country',
#        'dropornot', 'dropuser'],
#       dtype='object')

# %%
reduced_books_users_ratings.drop(["Unnamed: 0", "Unnamed: 0.1"], axis=1, inplace=True)
books_users_ratings.drop(["Unnamed: 0", "Unnamed: 0.1"], axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-54-95b679833a28> in <module>
#       1 reduced_books_users_ratings.drop(["Unnamed: 0", "Unnamed: 0.1"], axis=1, inplace=True)
# ----> 2 books_users_ratings.drop(["Unnamed: 0", "Unnamed: 0.1"], axis=1, inplace=True)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3695                                            index=index, columns=columns,
#    3696                                            level=level, inplace=inplace,
# -> 3697                                            errors=errors)
#    3698
#    3699     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
reduced_books_users_ratings.head()
reduced_books_users_ratings.assign(year_of_publication = pd.to_numeric(reduced_books_users_ratings.year_of_publication, downcast="integer"))
reduced_books_users_ratings.assign(year_of_publication = pd.to_numeric(reduced_books_users_ratings.year_of_publication, downcast="integer"))
books_users_ratings.head()
# Out:
#         user_id        isbn  book_rating  \
# 0         11676  038550120X           10
# 1         11676  0671537458            8
# 2         11676  0679776818            8
# 3         11676  0684867621            3
# 4         11676  8437606322            8
# 5         11676  3548603203            9
# 6         11676  0440498058            8
# 7         11676  0440225825            9
# 8         11676  0380005239           10
# 9         11676  3551551677            8
# 10        11676  0836220889            9
# 11        11676  3423201509            8
# 12        11676  002542730X            6
# 13        11676  0385504209            9
# 14        11676  2266104535            1
# 15        11676  2253063339            5
# 16        11676  8423310353            7
# 17        11676  0312966970            7
# 18        11676  0345354621            6
# 19        11676  0375760911            6
# 20        11676  0061087017            7
# 21        11676  0671793489            8
# ...

# %%
books_users_ratings.head()
# Out:
#    user_id        isbn  book_rating  \
# 0   276726  0155061224            5
# 1   276729  052165615X            3
# 2   276729  0521795028            6
# 3   276744  038550120X            7
# 4    11676  038550120X           10
#
#                                           book_title    book_author  \
# 0                                   Rites of Passage     Judith Rae
# 1                                     Help!: Level 1  Philip Prowse
# 2  The Amsterdam Connection : Level 4 (Cambridge ...    Sue Leather
# 3                                    A Painted House   JOHN GRISHAM
# 4                                    A Painted House   JOHN GRISHAM
#
#    year_of_publication                   publisher unique_isbn        age  \
# 0               2001.0                      Heinle  0155061224  34.786876
# 1               1999.0  Cambridge University Press  052165615X  16.000000
# 2               2001.0  Cambridge University Press  0521795028  16.000000
# ...
