# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle
import warnings

# %%
books = pd.read_csv("C:/University of Chicago/Machine Learning/Project\Machine-Learning-Book-Ratings/data/clean/books_clean.csv")
ratings = pd.read_csv("C:/University of Chicago/Machine Learning/Project\Machine-Learning-Book-Ratings/data/clean/ratings_clean.csv")
users = pd.read_csv("C:/University of Chicago/Machine Learning/Project\Machine-Learning-Book-Ratings/data/clean/users_clean.csv")

# %%
users.country.isnull().sum()
# Out:
# 4543

# %%
#unifying the books with ratings tables on isbn field
#number of entries in books table
len(books)
# Out:
# 266732

# %%
#ratings table size
len(ratings)
# Out:
# 433671

# %%
books_with_ratings = pd.merge(ratings, books, on='isbn')

# %%
#Checking if there are any rows with title/author missing
books_with_ratings.book_title.isnull().sum()
# Out:
# 0

# %%
books_with_ratings.book_author.isnull().sum()
# Out:
# 0

# %%
books_with_ratings.head()
# Out:
#    Unnamed: 0_x  user_id        isbn  book_rating  Unnamed: 0_y  \
# 0             1   276726  0155061224            5        225827
# 1             3   276729  052165615X            3        246849
# 2             4   276729  0521795028            6        246850
# 3             8   276744  038550120X            7          9295
# 4         48815    11676  038550120X           10          9295
#
#                                           book_title    book_author  \
# 0                                   Rites of Passage     Judith Rae
# 1                                     Help!: Level 1  Philip Prowse
# 2  The Amsterdam Connection : Level 4 (Cambridge ...    Sue Leather
# 3                                    A Painted House   JOHN GRISHAM
# 4                                    A Painted House   JOHN GRISHAM
#
#    year_of_publication                   publisher
# 0               2001.0                      Heinle
# 1               1999.0  Cambridge University Press
# 2               2001.0  Cambridge University Press
# 3               2001.0                   Doubleday
# 4               2001.0                   Doubleday

# %%
books_with_ratings =books_with_ratings.drop(columns =["Unnamed: 0_x", "Unnamed: 0_y"])

# %%
#unifying ISBN numbers
#looking the number of books with multiple isbn numbers
multiple_isbns = books_with_ratings.groupby('book_title').isbn.nunique()
multiple_isbns.value_counts()
# Out:
# 1     123409
# 2       7733
# 3       1426
# 4        457
# 5        179
# 6         81
# 7         37
# 8         24
# 9          8
# 10         6
# 16         2
# 15         2
# 14         2
# 13         2
# 12         2
# 11         2
# Name: isbn, dtype: int64

# %%
has_multiple_isbns= multiple_isbns.where(multiple_isbns>1) #sets NaN for those with just 1 isb

# %%
#removing the ones with just one isbn
has_multiple_isbns.dropna(inplace=True)

# %%
len(has_multiple_isbns)
# Out:
# 9963

# %%
#Create dictionary for books with multiple isbns
def make_isbn_dict(df):
    title_isbn_dict = {}
    for title in has_multiple_isbns.index:
        isbn_series = df.loc[df.book_title==title].isbn.unique() # returns only the unique ISBNs
        title_isbn_dict[title] = isbn_series.tolist()
    return title_isbn_dict

# %time dict_unique_isbn = make_isbn_dict(books_with_ratings)
# Out:
# Wall time: 11min 23s

# %%
with open('multiple_isbn_dict.pickle', 'wb') as handle:
    pickle.dump(dict_unique_isbn, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
# LOAD isbn_dict back into namespace
with open('multiple_isbn_dict.pickle', 'rb') as handle:
    multiple_isbn_dict = pickle.load(handle)

# %%
#checking the number of entries in the dictiionaries
len(multiple_isbn_dict)
# Out:
# 9963

# %%
# Adding 'unique_isbn' column to 'books_with_ratings' dataframe that includes the first ISBN if multiple ISBNS,or the single unique isbn
def add_unique_isbn_col(df):
    df['unique_isbn'] = df.apply(lambda row: multiple_isbn_dict[row.book_title][0] if row.book_title in multiple_isbn_dict.keys() else row.isbn, axis=1)
    return df

# %time books_with_ratings = add_unique_isbn_col(books_with_ratings)
# Out:
# Wall time: 12.2 s

# %%
#checking an example to see that the unique column has been added 
books_with_ratings[books_with_ratings.book_title=="Jane Eyre"].head()
# Out:
#         user_id        isbn  book_rating book_title       book_author  \
# 40062       387  1590071212            9  Jane Eyre  Charlotte Bronte
# 65551      2718  0451518845           10  Jane Eyre  Charlotte Bronte
# 65552     70205  0451518845            9  Jane Eyre  Charlotte Bronte
# 65553    218121  0451518845           10  Jane Eyre  Charlotte Bronte
# 109854     8370  0451523326            8  Jane Eyre  Charlotte Bronte
#
#         year_of_publication                  publisher unique_isbn
# 40062                2002.0        New Millenium Audio  1590071212
# 65551                1999.0  New Amer Library Classics  1590071212
# 65552                1999.0  New Amer Library Classics  1590071212
# 65553                1999.0  New Amer Library Classics  1590071212
# 109854               1988.0            Signet Classics  1590071212

# %%
#joining the users table on hte user_id field
books_users_ratings = books_with_ratings.merge(users, on='user_id')

# %%
books_users_ratings.head()
# Out:
#    user_id        isbn  book_rating  \
# 0   276726  0155061224            5
# 1   276729  052165615X            3
# 2   276729  0521795028            6
# 3   276744  038550120X            7
# 4    11676  038550120X           10
#
#                                           book_title    book_author  \
# 0                                   Rites of Passage     Judith Rae
# 1                                     Help!: Level 1  Philip Prowse
# 2  The Amsterdam Connection : Level 4 (Cambridge ...    Sue Leather
# 3                                    A Painted House   JOHN GRISHAM
# 4                                    A Painted House   JOHN GRISHAM
#
#    year_of_publication                   publisher unique_isbn  Unnamed: 0  \
# 0               2001.0                      Heinle  0155061224      276725
# 1               1999.0  Cambridge University Press  052165615X      276728
# 2               2001.0  Cambridge University Press  0521795028      276728
# 3               2001.0                   Doubleday  038550120X      276743
# 4               2001.0                   Doubleday  038550120X       11675
#
#          age      city        state   country
# 0  34.786876   seattle   washington       usa
# 1  16.000000    rijeka          n/a   croatia
# 2  16.000000    rijeka          n/a   croatia
# 3  34.786876  torrance   california       usa
# 4  34.786876       NaN          n/a       n/a

# %%
books_users_ratings.drop(columns = 'Unnamed: 0')
# Out:
#         user_id        isbn  book_rating  \
# 0        276726  0155061224            5
# 1        276729  052165615X            3
# 2        276729  0521795028            6
# 3        276744  038550120X            7
# 4         11676  038550120X           10
# 5         11676  0671537458            8
# 6         11676  0679776818            8
# 7         11676  0684867621            3
# 8         11676  3499230933            1
# 9         11676  8437606322            8
# 10        11676  8478442588            7
# 11        11676  0006379702            5
# 12        11676  3548603203            9
# 13        11676  0440498058            8
# 14        11676  8423996565            8
# 15        11676  0440225825            9
# 16        11676  0380005239           10
# 17        11676  3404921178            8
# 18        11676  3442437717            7
# 19        11676  3442446414            9
# 20        11676  3551551677            8
# 21        11676  0836220889            9
# 22        11676  3423201509            8
# 23        11676  8420636282            9
# 24        11676  002542730X            6
# 25        11676  0385504209            9
# 26        11676  2266104535            1
# 27        11676  2070419657            7
# 28        11676  2253063339            5
# 29        11676  2253144452            7
# ...         ...         ...          ...
# 375550   276086  076455381X            8
# 375551   276086  1885664001           10
# 375552   276094  0743247981            5
# 375553   276142  0671038672           10
# 375554   276171  0140275169            1
# 375555   276171  1586634151            7
# 375556   276205  9050182828            5
# 375557   276216  9700509222            5
# 375558   276221  1550741136            8
# 375559   276236  1567407617            5
# 375560   276265  0020130902            7
# 375561   276327  067163576X            9
# 375562   276396  1857989988            7
# 375563   276442  2070498492            6
# 375564   276442  2264032960            6
# 375565   276442  2862749796            7
# 375566   276465  0571202039            6
# 375567   276508  0130274917            6
# 375568   276508  0671746391            5
# 375569   276508  0870114573            7
# 375570   276556  0385314450            5
# 375571   276556  055337849x           10
# 375572   276618  3788097000            5
# 375573   276623  3442449715            5
# 375574   276647  0689822294           10
# 375575   276660  0583307841            8
# 375576   276664  0004703723            9
# 375577   276664  0140136908            7
# 375578   276664  0631189629            9
# 375579   276664  0747205051            7
#
#                                                book_title  \
# 0                                        Rites of Passage
# 1                                          Help!: Level 1
# 2       The Amsterdam Connection : Level 4 (Cambridge ...
# 3                                         A Painted House
# 4                                         A Painted House
# 5                                       Waiting to Exhale
# 6                       Birdsong: A Novel of Love and War
# 7                 The Girl Who Loved Tom Gordon : A Novel
# 8                                     Adressat unbekannt.
# 9                                           Anna Karenina
# 10                                 El Elogio de La Sombra
# 11                              My \Star Trek\" Memories"
# 12                                          Artemis Fowl.
# 13                                      A Wrinkle In Time
# 14                                   La hija del CanÃ­bal
# 15                                         Move to Strike
# 16                         Go Ask Alice (Avon/Flare Book)
# 17                            Nur der Tod ist ohne Makel.
# 18                                        Asche zu Asche.
# 19                   Mit dem KÃ?Â¼hlschrank durch Irland.
# 20                  Harry Potter und der Stein der Weisen
# 21                                      Calvin and Hobbes
# 22              Die Weiss Lowin / Contemporary German Lit
# 23                                          El Principito
# 24      Politically Correct Bedtime Stories: Modern Ta...
# 25                                      The Da Vinci Code
# 26            Et Si C'Etait Vrai / If This Were Only True
# 27                                                   Soie
# 28                                            Les Fourmis
# 29                           La RÃ?Â©volution des fourmis
# ...                                                   ...
# 375550                    Retail Business Kit for Dummies
# 375551  Providence: The Story of a Fifty Year Vision Q...
# 375552    Mama Gena's Owner's and Operator's Guide to Men
# 375553            Lights Out : Sleep, Sugar, and Survival
# 375554        An Intelligent Person's Guide to Philosophy
# 375568                        Simon & Schuster  0671746391  34.786876
# 375569                        Kodansha America  0870114573  34.786876
# 375570                              Dial Press  0385319428  34.786876
# 375571                                  Bantam  055347068X  34.786876
# 375572                            C.F. MÃ¼ller  3788097000  34.786876
# 375573                                Goldmann  3442449715  38.000000
# 375574  Simon & Schuster Children's Publishing  0689822294  13.000000
# 375575                HarperCollins Publishers  0583307841  15.000000
# 375576                        Trafalgar Square  0004703723  31.000000
# 375577                             Penguin USA  0140136908  31.000000
# 375578                    Blackwell Publishers  0631189629  31.000000
# 375579                                Headline  0747205051  31.000000
#
#                      city              state          country
# 0                 seattle         washington              usa
# 1                  rijeka                n/a          croatia
# 2                  rijeka                n/a          croatia
# 3                torrance         california              usa
# 4                     NaN                n/a              n/a
# 5                     NaN                n/a              n/a
# 6                     NaN                n/a              n/a
# 7                     NaN                n/a              n/a
# 8                     NaN                n/a              n/a
# 9                     NaN                n/a              n/a
# 10                    NaN                n/a              n/a
# 11                    NaN                n/a              n/a
# 12                    NaN                n/a              n/a
# 13                    NaN                n/a              n/a
# 14                    NaN                n/a              n/a
# 15                    NaN                n/a              n/a
# 16                    NaN                n/a              n/a
# 17                    NaN                n/a              n/a
# 18                    NaN                n/a              n/a
# 19                    NaN                n/a              n/a
# 20                    NaN                n/a              n/a
# 21                    NaN                n/a              n/a
# 22                    NaN                n/a              n/a
# 23                    NaN                n/a              n/a
# 24                    NaN                n/a              n/a
# 25                    NaN                n/a              n/a
# 26                    NaN                n/a              n/a
# 27                    NaN                n/a              n/a
# 28                    NaN                n/a              n/a
# 29                    NaN                n/a              n/a
# ...                   ...                ...              ...
# 375550        chapel hill     north carolina              usa
# 375551        chapel hill     north carolina              usa
# 375552           corrales         new mexico              usa
# 375553              delta   british columbia           canada
# 375554        los angeles         california              usa
# 375555        los angeles         california              usa
# 375556            sittard            limburg      netherlands
# 375557                ccp                ccp            chile
# 375558            calgary                                 NaN
# 375559             duluth            georgia              usa
# 375560        hot springs           arkansas              usa
# 375561               rome       newfoundland            italy
# 375562             dublin      county dublin          ireland
# 375563             genève             genève      switzerland
# 375564             genève             genève      switzerland
# 375565             genève             genève      switzerland
# 375566             oxford            england   united kingdom
# 375567  wilkes-barre area       pennsylvania              usa
# 375568  wilkes-barre area       pennsylvania              usa
# 375569  wilkes-barre area       pennsylvania              usa
# 375570          vancouver         washington              usa
# 375571          vancouver         washington              usa
# 375572          stuttgart            \n/a\".         germany"
# 375573          nuernberg             bayern          germany
# 375574  arlington heights           illinois              usa
# 375575          singapore                n/a        singapore
# 375576           daventry            england   united kingdom
# 375577           daventry            england   united kingdom
# 375578           daventry            england   united kingdom
# 375579           daventry            england   united kingdom
#
# [375580 rows x 12 columns]

# %%
books_users_ratings.to_csv("C:/University of Chicago/Machine Learning/Project/Machine-Learning-Book-Ratings/data/clean/books_users_ratings.csv")
